# %%
import pandas as pd

path = 'crime.csv'
df = pd.read_csv(path)

arrests_by_neighborhood = df.groupby('INCIDENTNEIGHBORHOOD').count()[df.columns[0]].reset_index()
arrests_by_neighborhood.columns = ['INCIDENTNEIGHBORHOOD', 'Number of Arrests']

sorted_arrests = arrests_by_neighborhood.sort_values(by='Number of Arrests', ascending=False)

pd.set_option('display.max_rows', None)

print(sorted_arrests.to_string (index=False))
# Out:
#        INCIDENTNEIGHBORHOOD  Number of Arrests
#   Central Business District               4439
#            South Side Flats               3496
#                     Carrick               2351
#              East Allegheny               2217
#              Homewood South               2090
#              Homewood North               1968
#                East Liberty               1889
#          Marshall-Shadeland               1516
#                       Bluff               1502
#            Mount Washington               1434
#                   Hazelwood               1396
#                   Brookline               1389
#    Lincoln-Lemington-Belmar               1362
#                   Knoxville               1336
#                    Sheraden               1285
#            Allegheny Center               1244
#                   Beechview               1201
#                  East Hills               1194
#            Brighton Heights               1114
#                 Perry South               1057
#                  Bloomfield                984
#                   Shadyside                971
#                   Allentown                947
#                 Middle Hill                932
#                     Larimer                879
#          Central North Side                853
#            Crawford-Roberts                839
#                 North Shore                814
#         Squirrel Hill South                812
#           South Side Slopes                801
#                    Fineview                796
#               Homewood West                764
#                    Garfield                722
#           Northview Heights                713
#       Spring Hill-City View                711
#           Bedford Dwellings                665
#                     Elliott                663
#             Crafton Heights                601
#                 Perry North                587
#               Highland Park                558
#                  Greenfield                537
#             Central Oakland                521
#              Strip District                503
#                 Beltzhoover                496
#                  Manchester                470
#               North Oakland                455
#                     Chateau                454
#                   Troy Hill                437
#       Central Lawrenceville                430
#                  Upper Hill                370
#               South Oakland                354
#                   Overbrook                331
#                West Oakland                325
#        California-Kirkbride                315
#                Outside City                315
#                   Arlington                312
#                 South Shore                301
#                Point Breeze                300
#             Terrace Village                297
#                  Banksville                291
#                    West End                290
#         Squirrel Hill North                290
#          Point Breeze North                289
#         Lower Lawrenceville                272
#                     Bon Air                267
#               Lincoln Place                227
#                    Westwood                226
#             Stanton Heights                223
#               Spring Garden                219
#                      Esplen                200
#            Duquesne Heights                191
#         Upper Lawrenceville                189
#                 Morningside                188
#                  Friendship                174
#                  Glen Hazel                169
#                 Polish Hill                166
#           Arlington Heights                155
#              Allegheny West                129
#                   Fairywood                127
#                     Windgap                124
#                Mount Oliver                124
#                        Hays                120
# Golden Triangle/Civic Arena                 83
#                     Oakwood                 82
#                 Summer Hill                 76
#               Outside State                 67
#              Outside County                 57
#                   St. Clair                 55
#               East Carnegie                 48
#              Chartiers City                 46
#              Swisshelm Park                 43
#               New Homestead                 39
#                   Ridgemont                 37
#               Regent Square                 37
#           Central Northside                 23
#             Mt. Oliver Boro                 18
#      Troy Hill-Herrs Island                  6
#     Mt. Oliver Neighborhood                  2

# %%
import pandas as pd

path = 'crime.csv'
df = pd.read_csv(path)

last_index_value = df.index[-1]

print("We are looking at:", last_index_value ,"arrests across Pittsburgh. This dataset ended 11/14/2023")
# Out:
# We are looking at: 66470 arrests across Pittsburgh. This dataset ended 11/14/2023

# %%
import pandas as pd

path = 'crime.csv'
df = pd.read_csv(path)

time = df.sort_values(by='ARRESTTIME')

print(time.loc[time.index[0], 'ARRESTTIME'])

print(time.loc[time.index[-1], 'ARRESTTIME'])
# Out:
# 1998-03-11T11:30:00
# 2023-11-14T03:00:00

# %%
import pandas as pd

path = 'crime.csv'
df = pd.read_csv(path)

arrests_by_neighborhood = df.groupby('INCIDENTNEIGHBORHOOD').size().reset_index()
arrests_by_neighborhood.columns = ['INCIDENTNEIGHBORHOOD', 'Number of Arrests']

sorted_arrests = arrests_by_neighborhood.sort_values(by='Number of Arrests', ascending=False)

chart = sorted_arrests.plot.bar(x='INCIDENTNEIGHBORHOOD', y='Number of Arrests', legend=None, figsize= (15,10))

chart.set_xlabel('Neighborhoods')
chart.set_ylabel('Number of Arrests')
# Out:
# Text(0, 0.5, 'Number of Arrests')

# %%
#sorting crime data by most prevalent offenses per neighborhood and how many times that offense occured

import pandas as pd

path = 'crime.csv'
df = pd.read_csv(path)

offensesperneighborhood = df.groupby(['INCIDENTNEIGHBORHOOD', 'OFFENSES']).size().reset_index()

offensesperneighborhood.columns = ['INCIDENTNEIGHBORHOOD', 'OFFENSES', 'Count']



sort = offensesperneighborhood.sort_values(by=['INCIDENTNEIGHBORHOOD', 'Count'], ascending=[True, False])

neighborhoods = sort['INCIDENTNEIGHBORHOOD'].unique()
for neighborhood in neighborhoods:
    print(f"\n{neighborhood}:")
    top3offenses = sort[sort['INCIDENTNEIGHBORHOOD'] == neighborhood].head(3)
    for index, row in top3offenses.iterrows():
        print(f"{row['OFFENSES']}: {row['Count']} occurrences")
# Out:
# Allegheny Center:
# 9015 Failure To Appear/Arrest on Attachment Order: 114 occurrences
# 13(a)(32) Paraphernalia - Use or Possession: 108 occurrences
# 9501 Bench Warrant: 92 occurrences
#
# Allegheny West:
# 9501 Bench Warrant: 9 occurrences
# 2701 Simple Assault.: 6 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 6 occurrences
#
# Allentown:
# 2701 Simple Assault.: 94 occurrences
# 9501 Bench Warrant: 65 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 52 occurrences
#
# Arlington:
# 2701 Simple Assault.: 47 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 16 occurrences
# 9501 Bench Warrant: 13 occurrences
#
# Arlington Heights:
# 2701 Simple Assault.: 18 occurrences
# 901 Criminal Attempt / 903 Criminal Conspiracy. / 2702 Aggravated Assault.: 10 occurrences
# 2701 Simple Assault. / 2718(a)(1) Strangulation - Applying Pressure to the Throat or Neck: 7 occurrences
#
# Banksville:
# 2701 Simple Assault.: 30 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 14 occurrences
# 9501 Bench Warrant: 14 occurrences
#
# Bedford Dwellings:
# 2701 Simple Assault.: 79 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 33 occurrences
# 9501 Bench Warrant: 31 occurrences
#
# Beechview:
# 2701 Simple Assault.: 107 occurrences
# 13(a)(31) Marijuana: Possession Small Amount: 52 occurrences
# 9501 Bench Warrant: 43 occurrences
#
# Beltzhoover:
# 2701 Simple Assault.: 42 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 25 occurrences
# 9501 Bench Warrant: 25 occurrences
#
# Bloomfield:
# 2701 Simple Assault.: 72 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 62 occurrences
# 9501 Bench Warrant: 43 occurrences
#
# Bluff:
# 9015 Failure To Appear/Arrest on Attachment Order: 135 occurrences
# 9501 Bench Warrant: 118 occurrences
# 13(a)(32) Paraphernalia - Use or Possession: 104 occurrences
#
# Bon Air:
# 2701 Simple Assault.: 17 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 11 occurrences
# 3802(a)(1) DUI - General Impairment: 10 occurrences
#
# Brighton Heights:
# 2701 Simple Assault.: 106 occurrences
# 9501 Bench Warrant: 54 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 49 occurrences
#
# Brookline:
# 2701 Simple Assault.: 146 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 66 occurrences
# 9501 Bench Warrant: 64 occurrences
#
# California-Kirkbride:
# 9501 Bench Warrant: 44 occurrences
# 2701 Simple Assault.: 22 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 14 occurrences
#
# Carrick:
# 2701 Simple Assault.: 215 occurrences
# 9501 Bench Warrant: 144 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 133 occurrences
#
# Central Business District:
# 9015 Failure To Appear/Arrest on Attachment Order: 319 occurrences
# 9501 Bench Warrant: 313 occurrences
# 2701 Simple Assault.: 213 occurrences
#
# Central Lawrenceville:
# 2701 Simple Assault.: 44 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 18 occurrences
# 9501 Bench Warrant: 17 occurrences
#
# Central North Side:
# 9501 Bench Warrant: 72 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 55 occurrences
# 2701 Simple Assault.: 42 occurrences
#
# Central Northside:
# 9501 Bench Warrant: 3 occurrences
# 13(a)(16) Possession of Controlled Substance: 2 occurrences
# 13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession / 3503(b)(1)(ii) Defiant Trespass Notice Posted by Sign(s): 2 occurrences
#
# Central Oakland:
# 3929 Retail Theft.: 31 occurrences
# 2701 Simple Assault.: 20 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 20 occurrences
#
# Chartiers City:
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 4 occurrences
# 2701 Simple Assault.: 3 occurrences
# 2701 Simple Assault. / 2702 Aggravated Assault. / 2709(a)(1) Harassment by Physical Contact, or Attempts or Threats: 2 occurrences
#
# Chateau:
# 9501 Bench Warrant: 34 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 21 occurrences
# 2701 Simple Assault.: 19 occurrences
#
# Crafton Heights:
# 2701 Simple Assault.: 83 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 28 occurrences
# 9501 Bench Warrant: 25 occurrences
#
# Crawford-Roberts:
# 9015 Failure To Appear/Arrest on Attachment Order: 71 occurrences
# 2701 Simple Assault.: 56 occurrences
# 9501 Bench Warrant: 45 occurrences
#
# Duquesne Heights:
# 2701 Simple Assault.: 13 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 8 occurrences
# 9501 Bench Warrant: 8 occurrences
#
# East Allegheny:
# 9015 Failure To Appear/Arrest on Attachment Order: 209 occurrences
# 9501 Bench Warrant: 153 occurrences
# 13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession: 100 occurrences
#
# East Carnegie:
# 2701 Simple Assault.: 6 occurrences
# 9093 Indirect Criminal Contempt: 5 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 2 occurrences
#
# East Hills:
# 2701 Simple Assault.: 114 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 57 occurrences
# 9501 Bench Warrant: 49 occurrences
#
# East Liberty:
# 3929 Retail Theft.: 220 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 110 occurrences
# 2701 Simple Assault.: 107 occurrences
#
# Elliott:
# 2701 Simple Assault.: 65 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 42 occurrences
# 9501 Bench Warrant: 41 occurrences
#
# Esplen:
# 9501 Bench Warrant: 18 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 15 occurrences
# 2701 Simple Assault.: 10 occurrences
#
# Fairywood:
# 2701 Simple Assault.: 19 occurrences
# 9501 Bench Warrant: 5 occurrences
# 3921 Theft by Unlawful Taking or Disposition.: 4 occurrences
#
# Fineview:
# 9015 Failure To Appear/Arrest on Attachment Order: 58 occurrences
# 13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession: 45 occurrences
# 2701 Simple Assault.: 40 occurrences
#
# Friendship:
# 2701 Simple Assault.: 26 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 13 occurrences
# 9501 Bench Warrant: 7 occurrences
#
# Garfield:
# 2701 Simple Assault.: 55 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 31 occurrences
# 9501 Bench Warrant: 29 occurrences
#
# Glen Hazel:
# 2701 Simple Assault.: 20 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 6 occurrences
# 9501 Bench Warrant: 4 occurrences
#
# Golden Triangle/Civic Arena:
# 9501 Bench Warrant: 6 occurrences
# 3701 Robbery.: 5 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 4 occurrences
#
# Greenfield:
# 2701 Simple Assault.: 41 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 35 occurrences
# 9501 Bench Warrant: 31 occurrences
#
# Hays:
# 2701 Simple Assault.: 10 occurrences
# 2702 Aggravated Assault.: 7 occurrences
# 9501 Bench Warrant: 7 occurrences
#
# Hazelwood:
# 9015 Failure To Appear/Arrest on Attachment Order: 92 occurrences
# 2701 Simple Assault.: 91 occurrences
# 9501 Bench Warrant: 86 occurrences
#
# Highland Park:
# 9501 Bench Warrant: 41 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 30 occurrences
# 2701 Simple Assault.: 29 occurrences
#
# Homewood North:
# 2701 Simple Assault.: 132 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 115 occurrences
# 9501 Bench Warrant: 108 occurrences
#
# Homewood South:
# 9015 Failure To Appear/Arrest on Attachment Order: 146 occurrences
# 9501 Bench Warrant: 118 occurrences
# 2701 Simple Assault.: 112 occurrences
#
# Homewood West:
# 13(a)(31) Marijuana: Possession Small Amount: 70 occurrences
# 2701 Simple Assault.: 50 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 32 occurrences
#
# Knoxville:
# 2701 Simple Assault.: 117 occurrences
# 9501 Bench Warrant: 84 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 71 occurrences
#
# Larimer:
# 9501 Bench Warrant: 50 occurrences
# 2701 Simple Assault.: 46 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 46 occurrences
#
# Lincoln Place:
# 2701 Simple Assault.: 23 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 12 occurrences
# 9093 Indirect Criminal Contempt: 11 occurrences
#
# Lincoln-Lemington-Belmar:
# 3929 Retail Theft.: 89 occurrences
# 2701 Simple Assault.: 86 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 71 occurrences
#
# Lower Lawrenceville:
# 2701 Simple Assault.: 25 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 14 occurrences
# 13(a)(32) Paraphernalia - Use or Possession: 7 occurrences
#
# Manchester:
# 2701 Simple Assault.: 38 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 24 occurrences
# 9501 Bench Warrant: 22 occurrences
#
# Marshall-Shadeland:
# 2701 Simple Assault.: 131 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 66 occurrences
# 9501 Bench Warrant: 60 occurrences
#
# Middle Hill:
# 2701 Simple Assault.: 84 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 59 occurrences
# 9501 Bench Warrant: 50 occurrences
#
# Morningside:
# 2701 Simple Assault.: 19 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 11 occurrences
# 13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession: 5 occurrences
#
# Mount Oliver:
# 2701 Simple Assault.: 11 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 7 occurrences
# 13(a)(31) Marijuana: Possession Small Amount: 5 occurrences
#
# Mount Washington:
# 2701 Simple Assault.: 138 occurrences
# 9501 Bench Warrant: 66 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 55 occurrences
#
# Mt. Oliver Boro:
# 903 Criminal Conspiracy. / 2701 Simple Assault.: 3 occurrences
# 13(a)(16) Possession of Controlled Substance: 1 occurrences
# 13(a)(16) Possession of Controlled Substance / 13(a)(30) Possession w/ Intent to Del. Controlled Substance / 13(a)(30)* Delivery of Controlled Substance: 1 occurrences
#
# Mt. Oliver Neighborhood:
# 2701 Simple Assault. / 2710 Ethnic Intimidation.: 1 occurrences
# 4906 False Reports to Law Enforcement Authorities.: 1 occurrences
#
# New Homestead:
# 2701 Simple Assault.: 4 occurrences
# 2701 Simple Assault. / 2709(a)(1) Harassment by Physical Contact, or Attempts or Threats: 2 occurrences
# 2701 Simple Assault. / 2718(a)(1) Strangulation - Applying Pressure to the Throat or Neck: 2 occurrences
#
# North Oakland:
# 9501 Bench Warrant: 63 occurrences
# 2701 Simple Assault.: 23 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 20 occurrences
#
# North Shore:
# 9501 Bench Warrant: 34 occurrences
# 2701 Simple Assault.: 31 occurrences
# 13(a)(31) Marijuana: Possession Small Amount: 29 occurrences
#
# Northview Heights:
# 2701 Simple Assault.: 73 occurrences
# 9501 Bench Warrant: 35 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 31 occurrences
#
# Oakwood:
# 2701 Simple Assault.: 8 occurrences
# 3929 Retail Theft.: 5 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 4 occurrences
#
# Outside City:
# 3925 Receiving Stolen Property.: 30 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 24 occurrences
# 9501 Bench Warrant: 23 occurrences
#
# Outside County:
# 3925 Receiving Stolen Property.: 10 occurrences
# 2701 Simple Assault.: 2 occurrences
# 3925 Receiving Stolen Property. / 1543 Driving While Operating Privilege is Suspended or Revoked.: 2 occurrences
#
# Outside State:
# 3925 Receiving Stolen Property.: 9 occurrences
# 9501 Bench Warrant: 7 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 4 occurrences
#
# Overbrook:
# 2701 Simple Assault.: 36 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 17 occurrences
# 9501 Bench Warrant: 16 occurrences
#
# Perry North:
# 2701 Simple Assault.: 50 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 32 occurrences
# 13(a)(31) Marijuana: Possession Small Amount: 30 occurrences
#
# Perry South:
# 2701 Simple Assault.: 83 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 48 occurrences
# 9501 Bench Warrant: 45 occurrences
#
# Point Breeze:
# 9015 Failure To Appear/Arrest on Attachment Order: 18 occurrences
# 2701 Simple Assault.: 11 occurrences
# 9501 Bench Warrant: 9 occurrences
#
# Point Breeze North:
# 9015 Failure To Appear/Arrest on Attachment Order: 12 occurrences
# 9501 Bench Warrant: 11 occurrences
# 2701 Simple Assault.: 9 occurrences
#
# Polish Hill:
# 2701 Simple Assault.: 12 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 7 occurrences
# 2702 Aggravated Assault.: 4 occurrences
#
# Regent Square:
# 13(a)(31) Marijuana: Possession Small Amount: 3 occurrences
# 1574 Permitting Unauthorized Person to Drive. / 1575 Permitting Violation of Title. / 1786 Required Financial Responsibility. / 4703 Operation of Vehicle without Official Certif. of Inspection / 4730 Violations of Use of Certificate of Inspection. / 7122 Altered, Forged or Counterfeit Documents and Plates / 4107(b)(2) Vehicle Equipment Standards: 2 occurrences
# 2701 Simple Assault.: 2 occurrences
#
# Ridgemont:
# 9093 Indirect Criminal Contempt: 4 occurrences
# 2701 Simple Assault.: 2 occurrences
# 3929 Retail Theft.: 2 occurrences
#
# Shadyside:
# 3929 Retail Theft.: 65 occurrences
# 3929(a)(1) Retail Theft; takes possession of, carries away, or transfers displayed merchandise: 59 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 47 occurrences
#
# Sheraden:
# 2701 Simple Assault.: 138 occurrences
# 9501 Bench Warrant: 69 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 56 occurrences
#
# South Oakland:
# 9501 Bench Warrant: 22 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 20 occurrences
# 2701 Simple Assault.: 15 occurrences
#
# South Shore:
# 9015 Failure To Appear/Arrest on Attachment Order: 18 occurrences
# 9501 Bench Warrant: 17 occurrences
# 2701 Simple Assault.: 10 occurrences
#
# South Side Flats:
# 9015 Failure To Appear/Arrest on Attachment Order: 170 occurrences
# 9501 Bench Warrant: 159 occurrences
# 2701 Simple Assault.: 146 occurrences
#
# South Side Slopes:
# 2701 Simple Assault.: 59 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 54 occurrences
# 9501 Bench Warrant: 46 occurrences
#
# Spring Garden:
# 9501 Bench Warrant: 21 occurrences
# 2701 Simple Assault.: 19 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 14 occurrences
#
# Spring Hill-City View:
# 2701 Simple Assault.: 65 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 46 occurrences
# 9501 Bench Warrant: 24 occurrences
#
# Squirrel Hill North:
# 9501 Bench Warrant: 18 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 13 occurrences
# 2701 Simple Assault.: 12 occurrences
#
# Squirrel Hill South:
# 2701 Simple Assault.: 43 occurrences
# 9501 Bench Warrant: 38 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 33 occurrences
#
# St. Clair:
# 2701 Simple Assault.: 6 occurrences
# 13(a)(32) Paraphernalia - Use or Possession: 4 occurrences
# 3304 Criminal Mischief. / 3502 Burglary.: 2 occurrences
#
# Stanton Heights:
# 2701 Simple Assault.: 27 occurrences
# 9093 Indirect Criminal Contempt: 11 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 9 occurrences
#
# Strip District:
# 2701 Simple Assault.: 31 occurrences
# 9501 Bench Warrant: 25 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 16 occurrences
#
# Summer Hill:
# 2701 Simple Assault.: 5 occurrences
# 3502 Burglary.: 5 occurrences
# 3802(a)(1) DUI - General Impairment / 3802(b) DUI - High Rate of Alchol - BAC >=.10% <.16%: 3 occurrences
#
# Swisshelm Park:
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 4 occurrences
# 13(a)(31) Marijuana: Possession Small Amount: 3 occurrences
# 2701 Simple Assault.: 3 occurrences
#
# Terrace Village:
# 2701 Simple Assault.: 32 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 17 occurrences
# 2701 Simple Assault. / 2718(a)(1) Strangulation - Applying Pressure to the Throat or Neck: 12 occurrences
#
# Troy Hill:
# 2701 Simple Assault.: 36 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 22 occurrences
# 9501 Bench Warrant: 20 occurrences
#
# Troy Hill-Herrs Island:
# 3502 Burglary.: 2 occurrences
# 13(a)(16) Possession of Controlled Substance / 13(a)(32) Paraphernalia - Use or Possession: 1 occurrences
# 2706 Terroristic Threats. / 4905 False Alarms to Agencies of Public Safety. / 5104 Resisting Arrest or Other Law Enforcement.: 1 occurrences
#
# Upper Hill:
# 2701 Simple Assault.: 44 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 17 occurrences
# 13(a)(31) Marijuana: Possession Small Amount: 15 occurrences
#
# Upper Lawrenceville:
# 2701 Simple Assault.: 19 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 8 occurrences
# 9501 Bench Warrant: 8 occurrences
#
# West End:
# 9501 Bench Warrant: 29 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 11 occurrences
# 9093 Indirect Criminal Contempt: 10 occurrences
#
# West Oakland:
# 9501 Bench Warrant: 26 occurrences
# 2701 Simple Assault.: 19 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 18 occurrences
#
# Westwood:
# 2701 Simple Assault.: 21 occurrences
# 9015 Failure To Appear/Arrest on Attachment Order: 11 occurrences
# 9501 Bench Warrant: 10 occurrences
#
# Windgap:
# 2701 Simple Assault.: 9 occurrences
# 2701 Simple Assault. / 2718(a)(1) Strangulation - Applying Pressure to the Throat or Neck: 9 occurrences
# 2701(a)(1) Simple Assault - Intent., Know., Reckless.Cause Bod. Injury: 6 occurrences

# %%
import pandas as pd

path = 'crime.csv'
df = pd.read_csv(path)

topoffenses = df["OFFENSES"].value_counts().nlargest(20)


topoffenses.plot.pie(figsize=(8, 8))

# %%
import pandas as pd

path = 'population.csv'
pop = pd.read_csv(path)

sortedpopulation = pop.sort_values(by='2020_Total_Population', ascending=False)

chart = sortedpopulation.plot.bar(x='Neighborhood', y='2020_Total_Population', legend=None, figsize= (15,10))

chart.set_xlabel('Neighborhoods')
chart.set_ylabel('Population Size')
# Out:
# Text(0, 0.5, 'Population Size')

# %%
import pandas as pd

path = 'population.csv'
pop = pd.read_csv(path)

pop_2010 = pop['2010_Total_Population'].sum()
pop_2020= pop['2020_Total_Population'].sum()


print("Pittsburgh's population in 2010 was" ,pop_2010,". In 2020, Pittsburgh's population was", pop_2020, ". This reveals that Pittsburgh's population has decreased by", pop_2020-pop_2010, "over ten years.")
# Out:
# Pittsburgh's population in 2010 was 305704 . In 2020, Pittsburgh's population was 302971 . This reveals that Pittsburgh's population has decreased by -2733 over ten years.

# %%
import pandas as pd

crime = 'crime.csv'
pop = 'population.csv'

crimedf= pd.read_csv(crime)
popdf = pd.read_csv(pop)

crimesin2020 = crimedf[crimedf['ARRESTTIME'].str.contains('2020', na=False)]
popin2020 = popdf.groupby('Neighborhood')['2020_Total_Population'].sum().reset_index()

merged = pd.merge(crimesin2020, popin2020, left_on='INCIDENTNEIGHBORHOOD', right_on='Neighborhood', how='inner')
crimesperneighborhood = merged.groupby('INCIDENTNEIGHBORHOOD').agg({merged.columns[0]: 'count', '2020_Total_Population': 'first'})
crimesperneighborhood = crimesperneighborhood.rename(columns={merged.columns[0]: '2020 Total Crimes', '2020_Total_Population': '2020 Total Population'})

crimesperneighborhood['Crime Rate'] = crimesperneighborhood['2020 Total Crimes'] / crimesperneighborhood['2020 Total Population']

sortedbyrate= crimesperneighborhood.sort_values(by='Crime Rate', ascending = False)

print(sortedbyrate)
# Out:
#                       2020 Total Crimes  2020 Total Population  Crime Rate
# INCIDENTNEIGHBORHOOD
# Chateau                              37                     19    1.947368
# South Shore                          37                     29    1.275862
# North Shore                          58                    301    0.192691
# Homewood West                       107                    642    0.166667
# West End                             31                    205    0.151220
# ...                                 ...                    ...         ...
# Swisshelm Park                        7                   1339    0.005228
# North Oakland                        55                  10691    0.005145
# New Homestead                         3                    917    0.003272
# Regent Square                         3                    971    0.003090
# Squirrel Hill North                  31                  11879    0.002610
#
# [84 rows x 3 columns]

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plot

neighborhoods=gpd.read_file('Data-Visualization/Neighborhoods/Neighborhoods_.shp')
crime = 'crime.csv'
pop = 'population.csv'


crimedf= pd.read_csv(crime)
popdf = pd.read_csv(pop)

crimesin2020 = crimedf[crimedf['ARRESTTIME'].str.contains('2020', na=False)]
popin2020 = popdf.groupby('Neighborhood')['2020_Total_Population'].sum().reset_index()

merged = pd.merge(crimesin2020, popin2020, left_on='INCIDENTNEIGHBORHOOD', right_on='Neighborhood', how='left')

crimesperneighborhood = merged.groupby('INCIDENTNEIGHBORHOOD').agg({merged.columns[0]: 'count', '2020_Total_Population': 'first'})
crimesperneighborhood = crimesperneighborhood.rename(columns={merged.columns[0]: '2020 Total Crimes', '2020_Total_Population': '2020 Total Population'})
crimesperneighborhood['Crime Rate'] = crimesperneighborhood['2020 Total Crimes'] / crimesperneighborhood['2020 Total Population']
crimesperneighborhood['Crime Rate'] = crimesperneighborhood['2020 Total Crimes'] / crimesperneighborhood['2020 Total Population']
neighborhoodcrime = neighborhoods.merge(crimesperneighborhood, left_on='hood', right_index=True, how='left')

fig, ax = plot.subplots(1, 1, figsize=(15, 10))
neighborhoodcrime.plot(column='Crime Rate', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.5', legend=True)
ax.set_title('2020 Crime Rate by each Pittsburgh Neighborhood')
plot.show()

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plot

path = 'crime.csv'
df = pd.read_csv(path)
neighborhoods=gpd.read_file('Data-Visualization/Neighborhoods/Neighborhoods_.shp')

arrests_by_neighborhood = df.groupby('INCIDENTNEIGHBORHOOD').size().reset_index()
arrests_by_neighborhood.columns = ['INCIDENTNEIGHBORHOOD', 'Number of Arrests']

mergedarrests = neighborhoods.merge(arrests_by_neighborhood, left_on='hood', right_on='INCIDENTNEIGHBORHOOD', how='left')


fig, ax = plot.subplots(1, 1, figsize=(15, 10))
mergedarrests.plot(column='Number of Arrests', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.5', legend=True)
ax.set_title('Number of Arrests in Each Pittsburgh Neighborhood')
plot.show()

# %% [markdown]
# As we can see from this map, South Side and the Central Business District have the highest number of arrests; however, when compared to crime rates, areas with a lower number of arrests have higher crime rate. This is because everything is relative to the population of each neighborhood.
